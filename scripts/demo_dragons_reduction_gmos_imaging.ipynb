# %%
__author__ = 'Monika Soraisam'
__email__ = 'monika.soraisam@noirlab.edu'

# %%
## if trouble with conda env https://stackoverflow.com/questions/70958434/unexpected-python-paths-in-conda-environment

# %% [markdown]
# ### Set up DRAGONS

# %%
import os
from pathlib import Path
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import datetime

# %%
# Now import the DRAGONS libraries 
import astrodata
import gemini_instruments
from recipe_system import cal_service
from gempy.adlibrary import dataselect
from gempy.utils import logutils

from recipe_system.reduction.coreReduce import Reduce
from gempy.scripts import showpars
from gempy.utils.showrecipes import showrecipes
from gempy.utils.showrecipes import showprims

# %%
## prep the reduction folder
def prep_reduction_folder(data_root, obsid):
    reduction_path = Path(f"{data_root}/{obsid}/reduction")

    if not reduction_path.exists():
        os.mkdir(reduction_path.as_posix())
        print (f"directory for dragons reduction created")
    
    ## change the cwd to the reduction folder
    os.chdir(reduction_path.as_posix())
    print(f"Current working directory is: {os.getcwd()}")

    ## write the configuration file 
    mydb = "dragons_for_goats.db" 
    mydb_path = reduction_path.as_posix() + '/' + mydb
    print (mydb_path)
    
    dragons_rc = reduction_path.as_posix() + '/dragonsrc'
    print (dragons_rc)
    
    with open(dragons_rc, "w") as f:
        f.write("[calibs]\ndatabases = {0} get store".format(mydb_path))

    return dragons_rc, mydb_path

# %% [markdown]
# ### GMOS imaging example -- GN-2015A-Q-86-5

# %%
data_path = "/Users/monika.soraisam/Desktop/tomdev/real_goats/goats_data/ZTF18abtvjfy/GEM"
obsid = 'GN-2015A-Q-86-5'  # GMOS imaging example 
dragons_rc, mydb_path = prep_reduction_folder(data_path, obsid)
# Out:
# Current working directory is: /Users/monika.soraisam/Desktop/tomdev/real_goats/goats_data/ZTF18abtvjfy/GEM/GN-2015A-Q-86-5/reduction
# /Users/monika.soraisam/Desktop/tomdev/real_goats/goats_data/ZTF18abtvjfy/GEM/GN-2015A-Q-86-5/reduction/dragons_for_goats.db
# /Users/monika.soraisam/Desktop/tomdev/real_goats/goats_data/ZTF18abtvjfy/GEM/GN-2015A-Q-86-5/reduction/dragonsrc

# %%
# initialize the calibration database and complete the set-up 
caldb = cal_service.LocalDB(mydb_path, force_init=True) #

# %% [markdown]
# ### Generate filelist for the data reduction

# %%
def generate_filelists(location, obsid):
    """
    Parameters
    ----------
    location: str
        Root folder where the Gemini data for a given target is located
    obsid: str
        Gemini observation ID 
    """

    
    all_files = [str(pp) for pp in list(Path(location+"/"+obsid).glob('*.fits'))]
    all_files.sort()
    print (f'The total number of files for observation ID {obsid} is {len(all_files)}')

    obs_types = ['OBJECT','BIAS','DARK','FLAT','ARC','PINHOLE','RONCHI','CAL','FRINGE','MOS MASK', 'BPM'] #fetched from Obs Type search field on GOA, which is relevant for DRAGONS

    all_meta = {}

    # Note that even if a few keywords are extracted below, thiis is just meant for demonstration puporses. 
    # If onyl these keywords are extracted in production, it will not align with  
    # implementation of item (2), allowing users to group/select preferred header keywords
    for K in obs_types:
        all_meta[K] = {'file':[],
                        'obs_class':[],
                        'group_id':[],
                        'exp':[],
                        'object':[],
                        'wave':[],
                        'waveband':[],
                        'date':[],
                        'roi':[],
                        }

    object_files = []
    for i,F in enumerate(all_files):
        ad = astrodata.open(F)

        if "BPM" in ad.tags or "UNPREPARED" in ad.tags: ## want only raw, i.e., "unprepared" files, but BPM is an exception, which is processed/prepared 
            K = ad.observation_type() ## astrodata header also has the observation type, which should match what's in the archive drop-down menu

        if "PREPARED" in ad.tags or "PROCESSED" in ad.tags: ## skip all "prepared"/"processed" files
            continue
            
        all_meta[K]['file'].append(F)
        all_meta[K]['obs_class'].append(ad.observation_class())
        
        # group_id seems to be not implemented for GNIRS spectroscopy yet
        if "GNIRS" in ad.instrument():
            all_meta[K]['group_id'].append(None)
        else:
            all_meta[K]['group_id'].append(ad.group_id())
        all_meta[K]['exp'].append(ad.exposure_time())
        all_meta[K]['object'].append(ad.object())
        all_meta[K]['wave'].append(ad.central_wavelength())
        all_meta[K]['waveband'].append(ad.wavelength_band())
        all_meta[K]['date'].append(ad.ut_date())
        all_meta[K]['roi'].append(ad.detector_roi_setting()) 
        #print (F.split('/')[-1], ad.object(), ad.tags)
    
    return all_meta

# %%
all_meta = generate_filelists(data_path, obsid)

for K,V in all_meta.items():
    if len(V['file'])==0:
        continue
    print (f"There are {len(V['file'])} files for observation type {K}")
# Out:
# The total number of files for observation ID GN-2015A-Q-86-5 is 693
# There are 360 files for observation type OBJECT
# There are 325 files for observation type BIAS

# %%
DF_bias = pd.DataFrame(all_meta['BIAS'])
#DF_bpm = pd.DataFrame(all_meta['BPM'])
DF_object = pd.DataFrame(all_meta['OBJECT'])

# %%
print (f"There are {len(np.unique(DF_object['object'].values))} science targets in this observation set, namely {np.unique(DF_object['object'].values)}")
# Out:
# There are 3 science targets in this observation set, namely ['J1655+2533' 'PG1633+099 F1' 'Twilight']

# %%
## add BPM to the calibration database (the BPM is already processed)
for F in caldb.list_files():
    print (F)

# Not able to add BPM for this observation ID, one had to manually download it because it is not yet packed in the associated calibrations
# for F in DF_bpm['file'].values:
#     caldb.add_cal(F)

# %% [markdown]
# ### Based on the **observation type** we see above for this data set, we can come up with the full reduction plan. E.g.,
# process bias -> process flat -> (process fringe->) process standard -> process science
#
# Note that for **some GMOS imaging** data, the step in bracket above needs to be done (see https://dragons.readthedocs.io/projects/gmosimg-drtutorial/en/v3.1.0/04_tips_and_tricks.html#tips-and-tricks). The detector and filter combination will indicate which data sets will require fringe frame (https://dragons.readthedocs.io/projects/gmosimg-drtutorial/en/v3.1.0/appendices/02_fringe_correction_tables.html#fringe-correction-tables).
#
# With the new implementation on GOATS where users can select alternative recipes and files, it should be straightforward for users to make fringe frames, if needed.

# %%
logutils.config(file_name='gmos_data_reduction.log') # logger

# %%
def dragons_reduce(filelist, alt_recipe=None, uparams=None, config_file=None):
    """
    Parameters
    ----------
    filelist: list 
        list of files of a given observation type
    alt_recipe: str
        alternative recipe name, if not using the default recipe
    uparams: list of tuples
        user supplied parameters for primitives in the recipe 
    config_file : str
        full path of the dragons config file to use 
    """
    reduce = Reduce()
    reduce.files.extend(filelist)
    if alt_recipe is not None:
        reduce.recipename = alt_recipe
    if uparams is not None:
        reduce.uparms = uparams 
    if config_file is not None:
        reduce.config_file = config_file
    reduce.runr()

# %%
## GOA associates a bunch of bias frames (going 6 months back or something) more than necessary, which at times impact the quality of reduced science data product
## Let's down-filter the number of bias files


for K in np.unique(DF_object['object'].values):
    temp = DF_object[DF_object['object'].values==K]
    print (f"Unique observation dates for OBJECT {K}: {np.unique(temp['date'].values)}") # Note that "Twilight" is not interesting for us


## we will "group" by group_id first. This grouping to an extent will have taken care of the bias frames grouping required to reduce the actual science targets
for K, V in DF_bias.groupby('group_id'):
    print ("Number of files:", len(V))
    ## Let's narrow it down by filtering on dates (something closer to the science target observation dates)
    mask = ((V['date'] > datetime.date(2015, 4, 17)) & (V['date'] < datetime.date(2015, 4, 30))) | ((V['date'] > datetime.date(2015, 6, 15)) & (V['date'] < datetime.date(2015, 6, 18)))
    print ("Number of filtered files now:", np.sum(mask))
    dragons_reduce(list(V['file'].values[mask]), config_file=dragons_rc)
# Out:
# All submitted files appear valid:
# /Users/monika.soraisam/Desktop/tomdev/real_goats/goats_data/ZTF18abtvjfy/GEM/GN-2015A-Q-86-5/N20150418S0453.fits ... /Users/monika.soraisam/Desktop/tomdev/real_goats/goats_data/ZTF18abtvjfy/GEM/GN-2015A-Q-86-5/N20150424S0381.fits, 25 files submitted.
# Unique observation dates for OBJECT J1655+2533: [datetime.date(2015, 4, 17) datetime.date(2015, 4, 30)
#  datetime.date(2015, 6, 15) datetime.date(2015, 6, 18)]
# Unique observation dates for OBJECT PG1633+099 F1: [datetime.date(2015, 4, 17)]
# Unique observation dates for OBJECT Twilight: [datetime.date(2015, 4, 9) datetime.date(2015, 4, 11)
#  datetime.date(2015, 4, 12) datetime.date(2015, 4, 19)
#  datetime.date(2015, 4, 26) datetime.date(2015, 6, 5)
#  datetime.date(2015, 6, 19)]
# Number of files: 75
# Number of filtered files now: 25
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1002'>
#   <div id="d3c07c28-80c8-4dff-962a-b2746b108fee" data-root-id="p1002" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"4900260f-d39a-47c0-a5e3-b8de6ca3a880":{"version":"3.4.2","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"p1002"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"p1003","attributes":{"plot_id":"p1002","comm_id":"4beac107c397401ba9ed9f847539836f","client_comm_id":"41e1cc6721a5452cb661a0843f837a46"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"copy_to_clipboard1","properties":[{"name":"fill","kind":"A ...
#   var render_items = [{"docid":"4900260f-d39a-47c0-a5e3-b8de6ca3a880","roots":{"p1002":"d3c07c28-80c8-4dff-962a-b2746b108fee"},"root_ids":["p1002"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>
# ================================================================================
# RECIPE: makeProcessedBias
# ================================================================================
#    PRIMITIVE: prepare
#    ------------------
#       PRIMITIVE: validateData
#       -----------------------
#       .
#       PRIMITIVE: standardizeStructure
#       -------------------------------
#       .
#       PRIMITIVE: standardizeHeaders
#       -----------------------------
#          PRIMITIVE: standardizeObservatoryHeaders
#          ----------------------------------------
#          Updating keywords that are common to all Gemini data
#          .
#          PRIMITIVE: standardizeInstrumentHeaders
#          ---------------------------------------
#          Updating keywords that are specific to GMOS
#          Updating keywords that are specific to GMOS
#          Updating keywords that are specific to GMOS
#          Updating keywords that are specific to GMOS
#          Updating keywords that are specific to GMOS
#          Updating keywords that are specific to GMOS
#          Updating keywords that are specific to GMOS
#          Updating keywords that are specific to GMOS
#          Updating keywords that are specific to GMOS
#          Updating keywords that are specific to GMOS
#          Updating keywords that are specific to GMOS
#          Updating keywords that are specific to GMOS
#          Updating keywords that are specific to GMOS
#          Updating keywords that are specific to GMOS
#          Updating keywords that are specific to GMOS
#          Updating keywords that are specific to GMOS
#          Updating keywords that are specific to GMOS
#          Updating keywords that are specific to GMOS
#          Updating keywords that are specific to GMOS
#          Updating keywords that are specific to GMOS
#          Updating keywords that are specific to GMOS
#          Updating keywords that are specific to GMOS
#          Updating keywords that are specific to GMOS
#          Updating keywords that are specific to GMOS
#          Updating keywords that are specific to GMOS
#          .
#       .
#       PRIMITIVE: standardizeWCS
#       -------------------------
#       .
#    .
#    PRIMITIVE: addDQ
#    ----------------
#    No BPMs found for N20150418S0453_prepared.fits and none supplied by the user.
#
#    No BPMs found for N20150418S0454_prepared.fits and none supplied by the user.
#
#    No BPMs found for N20150418S0455_prepared.fits and none supplied by the user.
#
#    No BPMs found for N20150418S0456_prepared.fits and none supplied by the user.
#
#    No BPMs found for N20150418S0457_prepared.fits and none supplied by the user.
#
#    No BPMs found for N20150419S0446_prepared.fits and none supplied by the user.
#
#    No BPMs found for N20150419S0447_prepared.fits and none supplied by the user.
#
#    No BPMs found for N20150419S0448_prepared.fits and none supplied by the user.
#
#    No BPMs found for N20150419S0449_prepared.fits and none supplied by the user.
#
#    No BPMs found for N20150419S0450_prepared.fits and none supplied by the user.
#
#    No BPMs found for N20150421S0607_prepared.fits and none supplied by the user.
#
#    No BPMs found for N20150421S0608_prepared.fits and none supplied by the user.
#
#    No BPMs found for N20150421S0638_prepared.fits and none supplied by the user.
#
#    No BPMs found for N20150421S0639_prepared.fits and none supplied by the user.
#
#    No BPMs found for N20150421S0640_prepared.fits and none supplied by the user.
#
#    No BPMs found for N20150422S0334_prepared.fits and none supplied by the user.
#
#    No BPMs found for N20150422S0335_prepared.fits and none supplied by the user.
#
#    No BPMs found for N20150422S0336_prepared.fits and none supplied by the user.
#
#    No BPMs found for N20150422S0337_prepared.fits and none supplied by the user.
#
#    No BPMs found for N20150422S0338_prepared.fits and none supplied by the user.
#
#    No BPMs found for N20150424S0377_prepared.fits and none supplied by the user.
#
#    No BPMs found for N20150424S0378_prepared.fits and none supplied by the user.
#
#    No BPMs found for N20150424S0379_prepared.fits and none supplied by the user.
#
#    No BPMs found for N20150424S0380_prepared.fits and none supplied by the user.
#
#    No BPMs found for N20150424S0381_prepared.fits and none supplied by the user.
#
#    .
#    PRIMITIVE: addVAR
#    -----------------
#    Adding the read noise component of the variance
#    .
#    PRIMITIVE: overscanCorrect
#    --------------------------
#       PRIMITIVE: subtractOverscan
#       ---------------------------
#          PRIMITIVE: subtractOverscan
#          ---------------------------
#          .
#       .
#       PRIMITIVE: trimOverscan
#       -----------------------
#       .
#    .
#    PRIMITIVE: stackBiases
#    ----------------------
#       PRIMITIVE: stackFrames
#       ----------------------
#       Combining 25 inputs with mean and varclip rejection
#       Combining extension 1.
#
#       Combining extension 2.
#
#       Combining extension 3.
#
#       Combining extension 4.
#
#       Combining extension 5.
#
#       Combining extension 6.
#
#       .
#    .
#    PRIMITIVE: makeIRAFCompatible
#    -----------------------------
#    .
#    PRIMITIVE: storeProcessedBias
#    -----------------------------
#       PRIMITIVE: storeCalibration
#       ---------------------------
#       /Users/monika.soraisam/Desktop/tomdev/real_goats/goats_data/ZTF18abtvjfy/GEM/GN-2015A-Q-86-5/reduction/dragons_for_goats.db: Storing calibrations/processed_bias/N20150418S0453_bias.fits as processed_bias
#       .
#    .
# 	Wrote N20150418S0453_bias.fits in output directory
#
# reduce completed successfully.
# All submitted files appear valid:
# /Users/monika.soraisam/Desktop/tomdev/real_goats/goats_data/ZTF18abtvjfy/GEM/GN-2015A-Q-86-5/N20150418S0503.fits ... /Users/monika.soraisam/Desktop/tomdev/real_goats/goats_data/ZTF18abtvjfy/GEM/GN-2015A-Q-86-5/N20150617S0472.fits, 55 files submitted.
# Number of files: 250
# Number of filtered files now: 55
# ================================================================================
# RECIPE: makeProcessedBias
# ================================================================================
#    PRIMITIVE: prepare
#    ------------------
#       PRIMITIVE: validateData
#       -----------------------
#       .
#       PRIMITIVE: standardizeStructure
#       -------------------------------
#       .
#       PRIMITIVE: standardizeHeaders
#       -----------------------------
#          PRIMITIVE: standardizeObservatoryHeaders
#          ----------------------------------------
#          Updating keywords that are common to all Gemini data
#          .
#          PRIMITIVE: standardizeInstrumentHeaders
#          ---------------------------------------
#          Updating keywords that are specific to GMOS
#          Updating keywords that are specific to GMOS
#          Updating keywords that are specific to GMOS
#          Updating keywords that are specific to GMOS
#          Updating keywords that are specific to GMOS
#          Updating keywords that are specific to GMOS
#          Updating keywords that are specific to GMOS
#          Updating keywords that are specific to GMOS
#          Updating keywords that are specific to GMOS
#          Updating keywords that are specific to GMOS
#          Updating keywords that are specific to GMOS
#          Updating keywords that are specific to GMOS
#          Updating keywords that are specific to GMOS
#          Updating keywords that are specific to GMOS
#          Updating keywords that are specific to GMOS
#          Updating keywords that are specific to GMOS
#          Updating keywords that are specific to GMOS
#          Updating keywords that are specific to GMOS
#          Updating keywords that are specific to GMOS
#          Updating keywords that are specific to GMOS
#          Updating keywords that are specific to GMOS
#          Updating keywords that are specific to GMOS
#          Updating keywords that are specific to GMOS
#          Updating keywords that are specific to GMOS
#          Updating keywords that are specific to GMOS
#          Updating keywords that are specific to GMOS
#          Updating keywords that are specific to GMOS
#          Updating keywords that are specific to GMOS
#          Updating keywords that are specific to GMOS
#          Updating keywords that are specific to GMOS
#          Updating keywords that are specific to GMOS
#          Updating keywords that are specific to GMOS
#          Updating keywords that are specific to GMOS
#          Updating keywords that are specific to GMOS
#          Updating keywords that are specific to GMOS
#          Updating keywords that are specific to GMOS
#          Updating keywords that are specific to GMOS
#          Updating keywords that are specific to GMOS
#          Updating keywords that are specific to GMOS
#          Updating keywords that are specific to GMOS
#          Updating keywords that are specific to GMOS
#          Updating keywords that are specific to GMOS
#          Updating keywords that are specific to GMOS
#          Updating keywords that are specific to GMOS
#          Updating keywords that are specific to GMOS
#          Updating keywords that are specific to GMOS
#          Updating keywords that are specific to GMOS
#          Updating keywords that are specific to GMOS
#          Updating keywords that are specific to GMOS
#          Updating keywords that are specific to GMOS
#          Updating keywords that are specific to GMOS
#          Updating keywords that are specific to GMOS
#          Updating keywords that are specific to GMOS
#          Updating keywords that are specific to GMOS
#          Updating keywords that are specific to GMOS
#          .
#       .
#       PRIMITIVE: standardizeWCS
#       -------------------------
#       .
#    .
#    PRIMITIVE: addDQ
#    ----------------
#    No BPMs found for N20150418S0503_prepared.fits and none supplied by the user.
#
#    No BPMs found for N20150418S0504_prepared.fits and none supplied by the user.
#
#    No BPMs found for N20150418S0505_prepared.fits and none supplied by the user.
#
#    No BPMs found for N20150418S0506_prepared.fits and none supplied by the user.
#
#    No BPMs found for N20150418S0507_prepared.fits and none supplied by the user.
#
#    No BPMs found for N20150419S0496_prepared.fits and none supplied by the user.
#
#    No BPMs found for N20150419S0497_prepared.fits and none supplied by the user.
#
#    No BPMs found for N20150419S0498_prepared.fits and none supplied by the user.
#
#    No BPMs found for N20150419S0499_prepared.fits and none supplied by the user.
#
#    No BPMs found for N20150419S0500_prepared.fits and none supplied by the user.
#
#    No BPMs found for N20150421S0696_prepared.fits and none supplied by the user.
#
#    No BPMs found for N20150421S0697_prepared.fits and none supplied by the user.
#
#    No BPMs found for N20150421S0698_prepared.fits and none supplied by the user.
#
#    No BPMs found for N20150421S0699_prepared.fits and none supplied by the user.
#
#    No BPMs found for N20150421S0700_prepared.fits and none supplied by the user.
#
#    No BPMs found for N20150422S0384_prepared.fits and none supplied by the user.
#
#    No BPMs found for N20150422S0385_prepared.fits and none supplied by the user.
#
#    No BPMs found for N20150422S0386_prepared.fits and none supplied by the user.
#
#    No BPMs found for N20150422S0387_prepared.fits and none supplied by the user.
#
#    No BPMs found for N20150422S0388_prepared.fits and none supplied by the user.
#
#    No BPMs found for N20150424S0427_prepared.fits and none supplied by the user.
#
#    No BPMs found for N20150424S0428_prepared.fits and none supplied by the user.
#
#    No BPMs found for N20150424S0429_prepared.fits and none supplied by the user.
#
#    No BPMs found for N20150424S0430_prepared.fits and none supplied by the user.
#
#    No BPMs found for N20150424S0431_prepared.fits and none supplied by the user.
#
#    No BPMs found for N20150425S0521_prepared.fits and none supplied by the user.
#
#    No BPMs found for N20150425S0522_prepared.fits and none supplied by the user.
#
#    No BPMs found for N20150425S0523_prepared.fits and none supplied by the user.
#
#    No BPMs found for N20150425S0524_prepared.fits and none supplied by the user.
#
#    No BPMs found for N20150425S0525_prepared.fits and none supplied by the user.
#
#    No BPMs found for N20150426S0472_prepared.fits and none supplied by the user.
#
#    No BPMs found for N20150426S0473_prepared.fits and none supplied by the user.
#
#    No BPMs found for N20150426S0474_prepared.fits and none supplied by the user.
#
#    No BPMs found for N20150426S0475_prepared.fits and none supplied by the user.
#
#    No BPMs found for N20150426S0476_prepared.fits and none supplied by the user.
#
#    No BPMs found for N20150427S0664_prepared.fits and none supplied by the user.
#
#    No BPMs found for N20150427S0665_prepared.fits and none supplied by the user.
#
#    No BPMs found for N20150427S0666_prepared.fits and none supplied by the user.
#
#    No BPMs found for N20150427S0667_prepared.fits and none supplied by the user.
#
#    No BPMs found for N20150427S0668_prepared.fits and none supplied by the user.
#
#    No BPMs found for N20150429S0274_prepared.fits and none supplied by the user.
#
#    No BPMs found for N20150429S0275_prepared.fits and none supplied by the user.
#
#    No BPMs found for N20150429S0276_prepared.fits and none supplied by the user.
#
#    No BPMs found for N20150429S0277_prepared.fits and none supplied by the user.
#
#    No BPMs found for N20150429S0278_prepared.fits and none supplied by the user.
#
#    No BPMs found for N20150616S0383_prepared.fits and none supplied by the user.
#
#    No BPMs found for N20150616S0384_prepared.fits and none supplied by the user.
#
#    No BPMs found for N20150616S0385_prepared.fits and none supplied by the user.
#
#    No BPMs found for N20150616S0386_prepared.fits and none supplied by the user.
#
#    No BPMs found for N20150616S0387_prepared.fits and none supplied by the user.
#
#    No BPMs found for N20150617S0468_prepared.fits and none supplied by the user.
#
#    No BPMs found for N20150617S0469_prepared.fits and none supplied by the user.
#
#    No BPMs found for N20150617S0470_prepared.fits and none supplied by the user.
#
#    No BPMs found for N20150617S0471_prepared.fits and none supplied by the user.
#
#    No BPMs found for N20150617S0472_prepared.fits and none supplied by the user.
#
#    .
#    PRIMITIVE: addVAR
#    -----------------
#    Adding the read noise component of the variance
#    .
#    PRIMITIVE: overscanCorrect
#    --------------------------
#       PRIMITIVE: subtractOverscan
#       ---------------------------
#          PRIMITIVE: subtractOverscan
#          ---------------------------
#          .
#       .
#       PRIMITIVE: trimOverscan
#       -----------------------
#       .
#    .
#    PRIMITIVE: stackBiases
#    ----------------------
#       PRIMITIVE: stackFrames
#       ----------------------
#       Combining 55 inputs with mean and varclip rejection
#       Combining extension 1.
#
#       Combining extension 2.
#
#       Combining extension 3.
#
#       Combining extension 4.
#
#       Combining extension 5.
#
#       Combining extension 6.
#
#       .
#    .
#    PRIMITIVE: makeIRAFCompatible
#    -----------------------------
#    .
#    PRIMITIVE: storeProcessedBias
#    -----------------------------
#       PRIMITIVE: storeCalibration
#       ---------------------------
#       /Users/monika.soraisam/Desktop/tomdev/real_goats/goats_data/ZTF18abtvjfy/GEM/GN-2015A-Q-86-5/reduction/dragons_for_goats.db: Storing calibrations/processed_bias/N20150418S0503_bias.fits as processed_bias
#       .
#    .
# 	Wrote N20150418S0503_bias.fits in output directory
#
# reduce completed successfully.

# %%
# Let's see how many files are now registered in the calibration database
for F in caldb.list_files():
    print (F)
# Out:
# FileData(name='N20150418S0453_bias.fits', path='/Users/monika.soraisam/Desktop/tomdev/real_goats/goats_data/ZTF18abtvjfy/GEM/GN-2015A-Q-86-5/reduction/calibrations/processed_bias')
# FileData(name='N20150418S0503_bias.fits', path='/Users/monika.soraisam/Desktop/tomdev/real_goats/goats_data/ZTF18abtvjfy/GEM/GN-2015A-Q-86-5/reduction/calibrations/processed_bias')

# %%
# Now, let's reduce the Twilight -- these are special type of flats. For this obs_ID, observers only gathered twilight flats and no regular flats

twilight = DF_object[DF_object['object'].values=='Twilight']

for K, V in twilight.groupby('group_id'):
    # ad = astrodata.open(V['file'].values[0])
    print (K, len(V), "\n")        
    dragons_reduce(list(V['file'].values), config_file=dragons_rc)

# %% [markdown]
# #### When one is reducing many exposures, for example, the case above with 276 files, then memory might be limited, so the intermediates files are qritten to disk. To get around this, user can increase the memory for the relevant primitive -- for the GMOS imaging routine, it's stackFrames (see below)

# %%
## Now let's reduce one of the remaining two science targets


target1 = DF_object[DF_object['object'].values=='J1655+2533']

for K, V in target1.groupby('group_id'):
    print (K, len(V), "\n")        
    # when dealing with image reduction, sometines users will need to increase the memory used for reduction to facilitate stacking 100's of frames. 
    # This can be controlled with a user supplied parameter as shown below (very easily done on the GOATS frontend with the editable recipe)
    dragons_reduce(list(V['file'].values), uparams=[('stackFrames:memory', None)], config_file=dragons_rc)

# %%
# Let's plot the reduced image

plt.close('all')
fig, ax = plt.subplots()
reduction_path = Path(f"{data_path}/{obsid}/reduction")
ad = astrodata.open(f'{reduction_path}/N20150417S0223_image.fits')
ad.info()
ax.imshow(ad[0].data, origin="lower", cmap='grey', vmin=np.percentile(ad[0].data, 10), vmax=np.percentile(ad[0].data, 80))
plt.show()
# Out:
# Filename: /Users/monika.soraisam/Desktop/tomdev/real_goats/goats_data/ZTF18abtvjfy/GEM/GN-2015A-Q-86-5/reduction/N20150417S0223_image.fits
# Tags: GEMINI GMOS IMAGE NORTH OVERSCAN_SUBTRACTED OVERSCAN_TRIMMED PREPARED
#     PROCESSED PROCESSED_SCIENCE SIDEREAL
#
# Pixels Extensions
# Index  Content                  Type              Dimensions     Format
# [ 0]   science                  NDAstroData       (1152, 1555)   float32
#           .variance             ADVarianceUncerta (1152, 1555)   float32
#           .mask                 ndarray           (1152, 1555)   uint16
#
# Other Extensions
#                Type        Dimensions
# .HISTORY       Table       (18, 4)
# .PROVENANCE    Table       (278, 4)
